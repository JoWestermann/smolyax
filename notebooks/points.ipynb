# %%
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

from points import *

# %% [markdown]
# # Leja Points

# %%
g = Leja([-1,1])
for n in range(13) :
    plt.scatter(g(n), [n]*(n+1))
plt.grid()

# %% [markdown]
# # Gauss-Hermite Points

# %%
g = GaussHermite(m=0, a=1)
for n in range(13) :
    plt.scatter(g(n), [n]*(n+1))
plt.grid()
